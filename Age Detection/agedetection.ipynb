# %%
import argparse
import cv2
import matplotlib.pyplot as plt

# %%
# !pip install py-agender[gpu]

# %%
from pyagender import PyAgender
agender = PyAgender() 
faces=agender.detect_genders_ages(cv2.imread("man1.jpg"))
faces["age"]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-792e130e07cd> in <module>()
#       1 from pyagender import PyAgender
#       2 agender = PyAgender()
# ----> 3 faces=agender.detect_genders_ages(cv2.imread("man1.jpg"))
#       4 faces["age"]
#
# /usr/local/lib/python3.6/dist-packages/pyagender/pyagender.py in detect_genders_ages(self, image)
#      48                  gender > 0.5 == female
#      49         """
# ---> 50         faceregions = self.detect_faces(image, margin=0.4)
#      51
#      52         for face in faceregions:
#
# /usr/local/lib/python3.6/dist-packages/pyagender/pyagender.py in detect_faces(self, image, margin)
#      96             array of face image rectangles {left: 34, top: 11, right: 122, bottom: 232, width:(r-l), height: (b-t)}
#      97         """
# ---> 98         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_kid= "/content/drive/My Drive/APS360/kid1.jpg"
path_manyoung="/content/drive/My Drive/APS360/man2.jpg"
path_woman="/content/drive/My Drive/APS360/girl1.jpg"
path_oldman="/content/drive/My Drive/APS360/oldman.jpg"

# %%
#basically showing all the images im using

img4 = cv2.imread('/content/drive/My Drive/APS360/oldman2.jpg')
plt.imshow(img4)

# %%
img = cv2.imread('/content/drive/My Drive/APS360/kid1.jpg')
plt.imshow(img)

# %%
img2 = cv2.imread('/content/drive/My Drive/APS360/man2.jpg')
plt.imshow(img2)

# %%
img3 = cv2.imread('/content/drive/My Drive/APS360/girl1.jpg')
plt.imshow(img3)

# %%
from pyagender import PyAgender

agender = PyAgender() 
# see available options in __init__() src

faces = agender.detect_genders_ages(cv2.imread("/content/drive/My Drive/APS360/girl1.jpg"))
faces[0]["agae"]
# Out:
# 30.32319409122283

# %%
from pyagender import PyAgender

agender = PyAgender() 
# see available options in __init__() src

faces = agender.detect_genders_ages(cv2.imread("/content/drive/My Drive/APS360/man2.jpg"))
faces[0]["age"]
# Out:
# 24.654445438292385

# %%
from pyagender import PyAgender

agender = PyAgender() 
# see available options in __init__() src

faces = agender.detect_genders_ages(cv2.imread("/content/drive/My Drive/APS360/kid1.jpg"))
faces[0]["age"]
# Out:
# 10.1879689285187

# %%
from pyagender import PyAgender

agender = PyAgender() 
# see available options in __init__() src

faces = agender.detect_genders_ages(cv2.imread("/content/drive/My Drive/APS360/oldman2.jpg"))
faces[0]["age"]
# Out:
# 65.0213323561893
